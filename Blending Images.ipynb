# %%
#importing all the necessary libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
#to view the plots n pictures in notebook
# %matplotlib inline

# %%
img1=cv2.imread('/Users/raviirt/Downloads/Computer-Vision-with-Python/DATA/dog_backpack.jpg')
img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2=cv2.imread('/Users/raviirt/Downloads/Computer-Vision-with-Python/DATA/watermark_no_copy.png')
img2=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1.shape
# Out:
# (1401, 934, 3)

# %%
img2.shape
# Out:
# (1280, 1277, 3)

# %%
img1=cv2.resize(img1,(1200,1200))

# %%
img2=cv2.resize(img2,(1200,1200))

# %%
img1.shape
# Out:
# (1200, 1200, 3)

# %%
img2.shape
# Out:
# (1200, 1200, 3)

# %%
blended_img=cv2.addWeighted(src1=img1,alpha=0.5,src2=img2,beta=0.5,gamma=0)

# %%
plt.imshow(blended_img)

# %%
img1=cv2.imread('/Users/raviirt/Downloads/Computer-Vision-with-Python/DATA/dog_backpack.jpg')
img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2=cv2.imread('/Users/raviirt/Downloads/Computer-Vision-with-Python/DATA/watermark_no_copy.png')
img2=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
img2=cv2.resize(img2,(600,600))

# %%
large_img=img1
small_img=img2

# %%
x_offset,y_offset=0,0

# %%
x_end=x_offset+small_img.shape[1]
y_end=y_offset+small_img.shape[0]

# %%
large_img[y_offset:y_end,x_offset:x_end]=small_img

# %%
plt.imshow(large_img)

# %%
img1=cv2.imread('/Users/raviirt/Downloads/Computer-Vision-with-Python/DATA/dog_backpack.jpg')
img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2=cv2.imread('/Users/raviirt/Downloads/Computer-Vision-with-Python/DATA/watermark_no_copy.png')
img2=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
img2=cv2.resize(img2,(600,600))

# %%
plt.imshow(img1)

# %%
img1.shape
# Out:
# (1401, 934, 3)

# %%
plt.imshow(img2)

# %%
img2.shape
# Out:
# (600, 600, 3)

# %%
x_offset=934-600
y_offset=1401-600

# %%
rows,cols,channels=img2.shape

# %%
rows
# Out:
# 600

# %%
cols
# Out:
# 600

# %%
channels
# Out:
# 3

# %%
roi=img1[y_offset:1401,x_offset:934]

# %%
plt.imshow(roi)

# %%
img2gray=cv2.cvtColor(img2,cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(img2gray,cmap='gray')

# %%
mask_inv=cv2.bitwise_not(img2gray)

# %%
plt.imshow(mask_inv,cmap='gray')
